# %% [markdown]
# Load a model then use it on test images.

# %%
import tensorflow as tf
from glob import glob
import os.path
import cv2
import scipy.misc
import numpy as np
import matplotlib.pyplot as plt

TEST_DIR = '../lyft_training_data/Test'
MODEL_DIR = 'saved_models/2018-05-17-0125'
IMG_SIZE = (256, 256)

def reshape_to_ori(mask, ori_img_shape):
    scale_height = int(ori_img_shape[0])
    scale_width = int(ori_img_shape[1])
    mask = cv2.resize(mask, (scale_width, scale_height), interpolation=cv2.INTER_NEAREST)
    return mask

def gen_test_output(sess, logits, image_pl, data_folder, image_shape):
    """
    Generate test output using the test images
    :param sess: TF session
    :param logits: TF Tensor for the logits
    :param image_pl: TF Placeholder for the image placeholder
    :param data_folder: Path to the folder that contains the datasets
    :param image_shape: Tuple - Shape of image
    :return: Output for for each test image
    """
    for image_file in glob(os.path.join(data_folder, '*.png')):
        ori_img = cv2.cvtColor(cv2.imread(image_file), cv2.COLOR_BGR2RGB)
        image = cv2.resize(ori_img, (image_shape[1], image_shape[0]))

        im_softmax = sess.run(
            [tf.nn.softmax(logits)],
            {image_pl: [image]})
        print("shape:", im_softmax[0].shape)
        im_softmax_road = im_softmax[0][:, 1].reshape(image_shape[0], image_shape[1])
        seg_road = \
          (im_softmax_road >= 0.50).reshape(image_shape[0], image_shape[1], 1)
            
        im_softmax_vehicle = im_softmax[0][:, 2].reshape(image_shape[0], image_shape[1])
        seg_vehicle = \
          (im_softmax_vehicle >= 0.50).reshape(image_shape[0], image_shape[1], 1)

        mask = np.dot(seg_road, np.array([[0, 255, 0, 127]])) + \
               np.dot(seg_vehicle, np.array([[255, 0, 0, 127]]))
        
        mask = reshape_to_ori(mask, ori_img.shape)

        mask = scipy.misc.toimage(mask, mode="RGBA")
        
        street_im = scipy.misc.toimage(ori_img)
        street_im.paste(mask, box=None, mask=mask)

        yield os.path.basename(image_file), np.array(street_im)
# Out:
# /home/jay/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# https://stackoverflow.com/questions/33759623/tensorflow-how-to-save-restore-a-model/47235448#47235448

sess = tf.Session()
signature_key = tf.saved_model.signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY

meta_graph_def = tf.saved_model.loader.load(sess,
                                            [tf.saved_model.tag_constants.SERVING], MODEL_DIR)

image_input = sess.graph.get_tensor_by_name('net_input:0')
logits = sess.graph.get_tensor_by_name('logits_1:0')

image_outputs = gen_test_output(sess, logits, image_input, TEST_DIR, IMG_SIZE)

images = []
image_names = []
for name, img in image_outputs:
    image_names.append(name)
    images.append(img)
# Out:
# INFO:tensorflow:Restoring parameters from b'saved_models/2018-05-21-0253/variables/variables'
# shape: (1, 256, 256, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5528a97f253a> in <module>()
#      14 images = []
#      15 image_names = []
# ---> 16 for name, img in image_outputs:
#      17     image_names.append(name)
#      18     images.append(img)
#
# <ipython-input-1-ee50af163c14> in gen_test_output(sess, logits, image_pl, data_folder, image_shape)
#      36         print("shape:", im_softmax.shape)
#      37
# ---> 38         im_softmax_road = im_softmax[:, 1].reshape(image_shape[0], image_shape[1])
#      39         seg_road =           (im_softmax_road >= 0.50).reshape(image_shape[0], image_shape[1], 1)
#      40
#
# ValueError: cannot reshape array of size 768 into shape (256,256)

# %%
for img in images:
    plt.figure(figsize=(15,10))
    plt.imshow(img)
    plt.show()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
x = np.array([[0, 0, 0],
              [2, 1, 2]])
x[1:,:][np.where(x[1:,:] == 1)] = 0
x
# Out:
# array([[0, 0, 0],
#        [2, 0, 2]])
